# %% [markdown]
# # More Frameworks
#
# * https://ai.gopubby.com/the-hidden-costs-of-langchain-crewai-pydanticai-and-others-why-popular-ai-frameworks-are-failing-77b9a40c16cf

# %% [markdown]
# ## Agno
#
# * https://ai.plainenglish.io/building-an-ai-agent-with-agno-a-step-by-step-guide-13542b2a5fb6
# * https://medium.com/@nomannayeem/pydanticai-agno-or-crewai-choosing-the-right-framework-for-your-ai-agent-e41dea879ce6
